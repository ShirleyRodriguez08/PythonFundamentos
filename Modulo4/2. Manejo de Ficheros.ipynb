# %% [markdown]
# # Manejo de Ficheros

# %% [markdown]
# Python nos permite trabajar en dos niveles diferentes con respecto al sistema de archivos y directorios. Uno de ellos, es a través del módulo os, que como su nombre lo indica, nos facilita el trabajo con todo el sistema de archivos y directorios, a nivel del propios Sistema Operativo. El segundo nivel -más simple-, es el que nos permite trabajar con archivos, manipulando su lectura y escritura a nivel de la aplicación y tratando a cada archivo como un objeto.

# %% [markdown]
# ## Objeto File
# ------------------------------

# %% [markdown]
# Al igual que sucede con otras variables, manipular una de ellas como un objeto File, es posible, cuando a ésta, se le asigna como valor un archivo.
# Para asignar a una variable un valor de tipo file, solo es necesario recurrir a la función integrada open(), la cuál está destinada a la apertura de un archivo.
#
# - La función integrada open(), recibe dos parámetros: – El primero de ellos, es la ruta hacia el archivo que se desea abrir
#
# - Y el segundo, el modo en el cual abrirlo

# %%
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\gon_2\\OneDrive - UNIVERSIDAD NACIONAL DE INGENIERIA\\Desktop\\PythonFundamentos\\Modulo4'

# %%
# Forma 1 de apertura a partir del método with 

ruta = os.getcwd()

file_path = os.path.join(ruta,'src','texto.txt') # './src/texto.txt'

with open(file_path,mode='r') as f:
    data = f.readlines()
    print(data[:200])
    

# Archivo se cierra de forma automática
# Out:
# ['Lorem ipsum dolor sit amet, consectetur adipiscing elit. Ut ac sollicitudin tortor, a porta sem. Nulla tempus urna sit amet mi cursus dictum. Mauris libero urna, luctus ac purus ac, faucibus rutrum diam. In sit amet congue velit. Vivamus gravida placerat egestas. Aenean imperdiet sem ac libero rutrum, ut sodales sem consequat. Sed eget quam nec nulla accumsan venenatis quis nec magna. Vestibulum ante ipsum primis in faucibus orci luctus et ultrices posuere cubilia curae; Sed tortor tellus, iaculis non magna et, cursus lobortis nibh. Interdum et malesuada fames ac ante ipsum primis in faucibus. Pellentesque habitant morbi tristique senectus et netus et malesuada fames ac turpis egestas. Maecenas at mauris nulla. Nulla porttitor arcu sit amet sagittis pulvinar. Sed et scelerisque eros, quis semper nibh. Praesent tincidunt posuere dictum.\n', '\n', 'Proin non ornare sapien. Integer eget tortor vitae elit vehicula facilisis. Nunc ultrices, lectus in suscipit eleifend, massa lorem consequat sem, vel maximus urna nibh a lacus. Nulla consectetur sem at enim rhoncus eleifend. Vestibulum ac tortor commodo, viverra erat ut, laoreet felis. In id rhoncus ex. Etiam posuere elit lacus, in interdum massa bibendum maximus. Ut in ante ante. Aenean consequat elit nibh, ut commodo lorem facilisis ac.\n', '\n', 'Praesent dapibus mauris facilisis dui suscipit, vel ornare velit venenatis. Sed orci neque, aliquam vitae nulla sed, convallis pulvinar odio. Morbi in ligula nec magna fermentum dapibus id a felis. In viverra nisl et aliquam finibus. Maecenas tempor tortor ac tortor accumsan, ac cursus neque varius. Pellentesque habitant morbi tristique senectus et netus et malesuada fames ac turpis egestas. Nam metus eros, faucibus eget congue gravida, egestas non risus. Interdum et malesuada fames ac ante ipsum primis in faucibus. Aenean hendrerit, mauris sed mattis mollis, felis elit sagittis ante, et aliquet urna tortor eget dui.']

# %%
# Forma 2 de apertura
f = open('./src/texto.txt', mode='r') # por defecto el modo de abrir el archivo es "lectura"

data = f.readlines() # readlines -> permite leer todas las líneas del archivo, en forma de lista
print(data[:200])
f.close()
# Out:
# ['Lorem ipsum dolor sit amet, consectetur adipiscing elit. Ut ac sollicitudin tortor, a porta sem. Nulla tempus urna sit amet mi cursus dictum. Mauris libero urna, luctus ac purus ac, faucibus rutrum diam. In sit amet congue velit. Vivamus gravida placerat egestas. Aenean imperdiet sem ac libero rutrum, ut sodales sem consequat. Sed eget quam nec nulla accumsan venenatis quis nec magna. Vestibulum ante ipsum primis in faucibus orci luctus et ultrices posuere cubilia curae; Sed tortor tellus, iaculis non magna et, cursus lobortis nibh. Interdum et malesuada fames ac ante ipsum primis in faucibus. Pellentesque habitant morbi tristique senectus et netus et malesuada fames ac turpis egestas. Maecenas at mauris nulla. Nulla porttitor arcu sit amet sagittis pulvinar. Sed et scelerisque eros, quis semper nibh. Praesent tincidunt posuere dictum.\n', '\n', 'Proin non ornare sapien. Integer eget tortor vitae elit vehicula facilisis. Nunc ultrices, lectus in suscipit eleifend, massa lorem consequat sem, vel maximus urna nibh a lacus. Nulla consectetur sem at enim rhoncus eleifend. Vestibulum ac tortor commodo, viverra erat ut, laoreet felis. In id rhoncus ex. Etiam posuere elit lacus, in interdum massa bibendum maximus. Ut in ante ante. Aenean consequat elit nibh, ut commodo lorem facilisis ac.\n', '\n', 'Praesent dapibus mauris facilisis dui suscipit, vel ornare velit venenatis. Sed orci neque, aliquam vitae nulla sed, convallis pulvinar odio. Morbi in ligula nec magna fermentum dapibus id a felis. In viverra nisl et aliquam finibus. Maecenas tempor tortor ac tortor accumsan, ac cursus neque varius. Pellentesque habitant morbi tristique senectus et netus et malesuada fames ac turpis egestas. Nam metus eros, faucibus eget congue gravida, egestas non risus. Interdum et malesuada fames ac ante ipsum primis in faucibus. Aenean hendrerit, mauris sed mattis mollis, felis elit sagittis ante, et aliquet urna tortor eget dui.']

# %%
# Valido si archivo se encuentra efectivamente cerrado
f.closed
# Out:
# True

# %% [markdown]
# ### Modos de Apertura

# %% [markdown]
# Por defecto un archivo se apertura en modo **lectura (r)** pero en la práctica existen muchos más modos los cuales nos permitiran escribir (w) o modificar un archivo ya existente

# %% [markdown]
# ![modo_apertura.png](attachment:acaf0496-a075-48fc-84a0-aa01b32c671a.png)<img src='./img/modo_apertura.PNG'>

# %% [markdown]
# <img src='./img/modo_apertura2.PNG'>

# %% [markdown]
# ### Métodos de Archivos

# %% [markdown]
# El objeto file, entre sus métodos más frecuentes, dispone de los siguientes

# %% [markdown]
# <img src='./img/metodos_files.PNG'>

# %% [markdown]
# ## Lectura

# %%
# Ruta donde leeremos el fichero, r indica lectura (por defecto ya es r)
fichero = open('./src/texto.txt','r')  

# Lectura completa
texto = fichero.read() #  read -> Metodo que permite la lectura de todo el archivo

# Cerramos el fichero
fichero.close()  

print(texto)
# Out:
# Lorem ipsum dolor sit amet, consectetur adipiscing elit. Ut ac sollicitudin tortor, a porta sem. Nulla tempus urna sit amet mi cursus dictum. Mauris libero urna, luctus ac purus ac, faucibus rutrum diam. In sit amet congue velit. Vivamus gravida placerat egestas. Aenean imperdiet sem ac libero rutrum, ut sodales sem consequat. Sed eget quam nec nulla accumsan venenatis quis nec magna. Vestibulum ante ipsum primis in faucibus orci luctus et ultrices posuere cubilia curae; Sed tortor tellus, iaculis non magna et, cursus lobortis nibh. Interdum et malesuada fames ac ante ipsum primis in faucibus. Pellentesque habitant morbi tristique senectus et netus et malesuada fames ac turpis egestas. Maecenas at mauris nulla. Nulla porttitor arcu sit amet sagittis pulvinar. Sed et scelerisque eros, quis semper nibh. Praesent tincidunt posuere dictum.
#
# Proin non ornare sapien. Integer eget tortor vitae elit vehicula facilisis. Nunc ultrices, lectus in suscipit eleifend, massa lorem consequat sem, vel maximus urna nibh a lacus. Nulla consectetur sem at enim rhoncus eleifend. Vestibulum ac tortor commodo, viverra erat ut, laoreet felis. In id rhoncus ex. Etiam posuere elit lacus, in interdum massa bibendum maximus. Ut in ante ante. Aenean consequat elit nibh, ut commodo lorem facilisis ac.
#
# Praesent dapibus mauris facilisis dui suscipit, vel ornare velit venenatis. Sed orci neque, aliquam vitae nulla sed, convallis pulvinar odio. Morbi in ligula nec magna fermentum dapibus id a felis. In viverra nisl et aliquam finibus. Maecenas tempor tortor ac tortor accumsan, ac cursus neque varius. Pellentesque habitant morbi tristique senectus et netus et malesuada fames ac turpis egestas. Nam metus eros, faucibus eget congue gravida, egestas non risus. Interdum et malesuada fames ac ante ipsum primis in faucibus. Aenean hendrerit, mauris sed mattis mollis, felis elit sagittis ante, et aliquet urna tortor eget dui.

# %%
type(texto)
# Out:
# str

# %% [markdown]
# También se puede leer un fichero utilizando la instrucción estándar with de la siguiente forma:

# %%
with open('./src/texto.txt', "r") as fichero:
    for linea in fichero:
        print(linea)
# Out:
# Lorem ipsum dolor sit amet, consectetur adipiscing elit. Ut ac sollicitudin tortor, a porta sem. Nulla tempus urna sit amet mi cursus dictum. Mauris libero urna, luctus ac purus ac, faucibus rutrum diam. In sit amet congue velit. Vivamus gravida placerat egestas. Aenean imperdiet sem ac libero rutrum, ut sodales sem consequat. Sed eget quam nec nulla accumsan venenatis quis nec magna. Vestibulum ante ipsum primis in faucibus orci luctus et ultrices posuere cubilia curae; Sed tortor tellus, iaculis non magna et, cursus lobortis nibh. Interdum et malesuada fames ac ante ipsum primis in faucibus. Pellentesque habitant morbi tristique senectus et netus et malesuada fames ac turpis egestas. Maecenas at mauris nulla. Nulla porttitor arcu sit amet sagittis pulvinar. Sed et scelerisque eros, quis semper nibh. Praesent tincidunt posuere dictum.
#
#
#
# Proin non ornare sapien. Integer eget tortor vitae elit vehicula facilisis. Nunc ultrices, lectus in suscipit eleifend, massa lorem consequat sem, vel maximus urna nibh a lacus. Nulla consectetur sem at enim rhoncus eleifend. Vestibulum ac tortor commodo, viverra erat ut, laoreet felis. In id rhoncus ex. Etiam posuere elit lacus, in interdum massa bibendum maximus. Ut in ante ante. Aenean consequat elit nibh, ut commodo lorem facilisis ac.
#
#
#
# Praesent dapibus mauris facilisis dui suscipit, vel ornare velit venenatis. Sed orci neque, aliquam vitae nulla sed, convallis pulvinar odio. Morbi in ligula nec magna fermentum dapibus id a felis. In viverra nisl et aliquam finibus. Maecenas tempor tortor ac tortor accumsan, ac cursus neque varius. Pellentesque habitant morbi tristique senectus et netus et malesuada fames ac turpis egestas. Nam metus eros, faucibus eget congue gravida, egestas non risus. Interdum et malesuada fames ac ante ipsum primis in faucibus. Aenean hendrerit, mauris sed mattis mollis, felis elit sagittis ante, et aliquet urna tortor eget dui.

# %%
# Ruta donde leeremos el fichero, r indica lectura (por defecto ya es r)
fichero = open('./src/texto.txt','r')  

# Lectura completa
lista_texto = fichero.readlines() #  read -> Metodo que permite la lectura de todo el archivo
# Cerramos el fichero
fichero.close()

# %%
lista_texto
# Out:
# ['Lorem ipsum dolor sit amet, consectetur adipiscing elit. Ut ac sollicitudin tortor, a porta sem. Nulla tempus urna sit amet mi cursus dictum. Mauris libero urna, luctus ac purus ac, faucibus rutrum diam. In sit amet congue velit. Vivamus gravida placerat egestas. Aenean imperdiet sem ac libero rutrum, ut sodales sem consequat. Sed eget quam nec nulla accumsan venenatis quis nec magna. Vestibulum ante ipsum primis in faucibus orci luctus et ultrices posuere cubilia curae; Sed tortor tellus, iaculis non magna et, cursus lobortis nibh. Interdum et malesuada fames ac ante ipsum primis in faucibus. Pellentesque habitant morbi tristique senectus et netus et malesuada fames ac turpis egestas. Maecenas at mauris nulla. Nulla porttitor arcu sit amet sagittis pulvinar. Sed et scelerisque eros, quis semper nibh. Praesent tincidunt posuere dictum.\n',
#  '\n',
#  'Proin non ornare sapien. Integer eget tortor vitae elit vehicula facilisis. Nunc ultrices, lectus in suscipit eleifend, massa lorem consequat sem, vel maximus urna nibh a lacus. Nulla consectetur sem at enim rhoncus eleifend. Vestibulum ac tortor commodo, viverra erat ut, laoreet felis. In id rhoncus ex. Etiam posuere elit lacus, in interdum massa bibendum maximus. Ut in ante ante. Aenean consequat elit nibh, ut commodo lorem facilisis ac.\n',
#  '\n',
#  'Praesent dapibus mauris facilisis dui suscipit, vel ornare velit venenatis. Sed orci neque, aliquam vitae nulla sed, convallis pulvinar odio. Morbi in ligula nec magna fermentum dapibus id a felis. In viverra nisl et aliquam finibus. Maecenas tempor tortor ac tortor accumsan, ac cursus neque varius. Pellentesque habitant morbi tristique senectus et netus et malesuada fames ac turpis egestas. Nam metus eros, faucibus eget congue gravida, egestas non risus. Interdum et malesuada fames ac ante ipsum primis in faucibus. Aenean hendrerit, mauris sed mattis mollis, felis elit sagittis ante, et aliquet urna tortor eget dui.']

# %%
len(lista_texto)
# Out:
# 5

# %% [markdown]
# ## Escritura

# %%
texto = "Una línea con texto\nOtra línea con texto"

print(texto)
# Out:
# Una línea con texto
# Otra línea con texto

# %%
texto = "Una línea con texto\nOtra línea con texto"

# Ruta donde crearemos el fichero, w indica escritura (puntero al principio)
# De existir el archivo, este será eliminado y creado uno nuevo 
with open('./src/fichero.txt','w') as f:
    # Escribimos el texto
    f.write(texto)

# %%
with open('./src/fichero.txt','r') as f:
    # Escribimos el texto
    data = f.readlines()

# %%
data
# Out:
# ['Una línea con texto\n', 'Otra línea con texto']

# %% [markdown]
# Este modo nos permite añadir datos al final de un fichero:

# %%
# Ruta donde leeremos el fichero, a indica extensión (puntero al final)
with open('./src/fichero.txt','a') as f:
    f.write('\nmás lineas')

# %% [markdown]
# La variante 'a+' permite crear el fichero si no existe:

# %%
# Ruta archivo del tipo a

lista_palabras =["mayonesa\n","keptchup\n","mostaza"]

with open('./src/fichero_inventado.txt','a') as f:
    #f.write('\nhola mundo')
    f.writelines(lista_palabras)

# %% [markdown]
# ## Lectura con escritura

# %% [markdown]
# Se puede abrir un fichero en modo lectura con escritura, pero éste debe existir préviamente. Además por defecto el puntero estará al principio y si escribimos algo sobreescribiremos el contenido actual, así que prestad atención a los saltos de línea y caracteres especiales:

# %%
# Creamos un fichero de prueba con 4 líneas
fichero = open('./src/fichero2.txt','w')
texto = "Línea 1\nLínea 2\nLínea 3\nLínea 4"
fichero.write(texto)
fichero.close() # guardar cambios
# Out:
# 31

# %%
#fichero.close()

# %%
# Lo abrimos en lectura con escritura y escribimos algo
fichero = open('./src/fichero2.txt','r+') # modo lectura y escritura -> r+
fichero.write("56789")
# Out:
# 5

# %%
fichero.close() # siempre debo usar el close en este modo de apertura

# %%
# Volvemos a ponter el puntero al inicio y leemos hasta el final
fichero.seek(0)
l = fichero.read()
print(l)
fichero.close()
# Out:
# 56789 1
# Línea 2
# Línea 3
# Línea 4

# %% [markdown]
# ### Modificar una línea

# %% [markdown]
# Para lograr este fin lo mejor es leer todas las líneas en una lista, modificar la línea en la lista, posicionar el puntero al principio y reescribir de nuevo todas las líneas:

# %%
fichero = open('./src/fichero2.txt','r+')
listado_texto = fichero.readlines()

listado_texto
# Out:
# ['56789 1\n', 'Línea 2\n', 'Esta es la línea 3 modificada\n', 'Línea 4']

# %%
listado_texto = listado_texto.replace("línea", "casa")

# %%
listado_texto
# Out:
# '56789 1\nLínea 2\nEsta es la casa 3 modificada\nLínea 4'

# %%
# Modificamos la línea que queramos a partir del índice
listado_texto[2] = "Esta es la línea 3 modificada\n"

# Volvemos a ponter el puntero al inicio y reescribimos
fichero.seek(0)
fichero.writelines(listado_texto)
fichero.close()

# Leemos el fichero de nuevo
with open("./src/fichero2.txt", "r") as fichero:
    print(fichero.read())
# Out:
# 56789 1
# Línea 2
# Esta es la línea 3 modificada
# Línea 4

# %% [markdown]
# ### <a href='https://docs.python.org/2.4/lib/standard-encodings.html'>Encoding</a>

# %% [markdown]
# **encoding** es el nombre de la codificación utilizada para decodificar o codificar el archivo. Esto solo debe usarse en modo texto. La codificación predeterminada es dependiente de la plataforma, pero cualquier codificación compatible con Python se puede utilizar.

# %% [markdown]
# Más conocidos:
#
# - utf-8
# - latin1
# - ascii

# %% [markdown]
# #### Lectura sin encoding con texto español

# %%
with open('./src/fichero_esp.txt','r') as f:
    texto = f.read()
    print(texto)
# Out:
# Este es un archivo de texto en espaÃ±ol

# %% [markdown]
# #### Lectura con encoding utf-8

# %%
with open('./src/fichero_esp.txt',encoding='utf-8') as f:
    texto = f.read()
    print(texto)
# Out:
# Este es un archivo de texto en español

# %% [markdown]
# # EJERCICIOS
# ----------------------------

# %% [markdown]
# <h3>1.</h3>
#
# En este ejercicio deberás crear un script llamado <code>personas.py</code> que lea los datos de un fichero de texto, que transforme cada fila en un diccionario y lo añada a una lista llamada personas. Luego rocorre las personas de la lista y para cada una muestra de forma amigable todos sus campos.
#
# El fichero de texto se denominará <code>personas.txt</code> y tendrá el siguiente contenido en texto plano (créalo previamente):

# %% [markdown]
# <code>1;Carlos;Pérez;05/01/1989
# 2;Manuel;Heredia;26/12/1973
# 3;Rosa;Campos;12/06/1961
# 4;David;García;25/07/2006</code>

# %%
# %%time

with open('./src/personas.txt',encoding='utf-8') as f:
    lista_string = f.readlines() 

personas = []
for linea in lista_string:
    
    texto_split = linea.split(';')
    
    dicx = {}
    dicx['indice'] =  texto_split[0]
    dicx['nombre'] = texto_split[1]
    dicx['apellido'] = texto_split[2]
    dicx['nacimiento'] = texto_split[3].strip()
    personas.append(dicx)
    
# muestro informacion de forma amigable
for p in personas:    
    print("------{}-----".format(p['indice']))
    for k in p.keys():
        if k != 'indice':
            print(f"{k}: {p[k]}")
# Out:
# ------1-----
# nombre: Carlos
# apellido: Pérez
# nacimiento: 05/01/1989
# ------2-----
# nombre: Manuel
# apellido: Heredia
# nacimiento: 26/12/1973
# ------3-----
# nombre: Rosa
# apellido: Campos
# nacimiento: 12/06/1961
# ------4-----
# nombre: David
# apellido: García
# nacimiento: 25/07/2006
# Wall time: 1.98 ms

# %%
# %%time

with open('./src/personas.txt',encoding='utf-8') as f:
    personas = []
    for linea in f:
        texto_split = linea.split(';')
    
        dicx = {}
        dicx['indice'] =  texto_split[0]
        dicx['nombre'] = texto_split[1]
        dicx['apellido'] = texto_split[2]
        dicx['nacimiento'] = texto_split[3].strip()
        personas.append(dicx)
    pass
    
# muestro informacion de forma amigable
for p in personas:    
    print("------{}-----".format(p['indice']))
    for k in p.keys():
        if k != 'indice':
            print(f"{k}: {p[k]}")
# Out:
# ------1-----
# nombre: Carlos
# apellido: Pérez
# nacimiento: 05/01/1989
# ------2-----
# nombre: Manuel
# apellido: Heredia
# nacimiento: 26/12/1973
# ------3-----
# nombre: Rosa
# apellido: Campos
# nacimiento: 12/06/1961
# ------4-----
# nombre: David
# apellido: García
# nacimiento: 25/07/2006
# Wall time: 2.99 ms
